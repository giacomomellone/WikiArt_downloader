# %% [markdown]
# ### Download high-resolution images from wikiArt

# %%
import requests
import os
from tqdm import tqdm
from bs4 import BeautifulSoup as bs
from urllib.parse import urljoin, urlparse

# %%
def is_valid(url):
    """
    Checks whether `url` is a valid URL.
    """
    parsed = urlparse(url)
    return bool(parsed.netloc) and bool(parsed.scheme)

# %%
def get_all_images(url):
    """
    Returns all image URLs on a single `url`
    """
    soup = bs(requests.get(url).content, "html.parser")
    urls = []
    for img in tqdm(soup.find_all("img"), "Extracting images"):
        img_url = img.attrs.get("src")
        if not img_url:
            # if img does not contain src attribute, just skip
            continue
        # make the URL absolute by joining domain with the URL that is just extracted
        img_url = urljoin(url, img_url)
        # remove URLs like '/hsts-pixel.gif?c=3.2.5'
        try:
            pos = img_url.index("?")
            img_url = img_url[:pos]
        except ValueError:
            pass
        # finally, if the url is valid
        if is_valid(img_url):
            img_url = img_url.split('!', 1)[0]
            urls.append(img_url)
    return urls

# %%
def get_all_addresses(addresses):
    """
    Returns all image URLs on a single `url`
    """
    soup = bs(requests.get(addresses).content, "html.parser")
    urls = []
    
    for img in tqdm(soup.findAll("li", {"class": "painting-list-text-row"}), "Extracting images"):
        img_url = img.a.get('href')
        img_url = img_url.split('/', 2)[2]
        img_url = "https://uploads0.wikiart.org/images/" + img_url + ".jpg"
        if not img_url:
            # if img does not contain src attribute, just skip
            continue
        # make the URL absolute by joining domain with the URL that is just extracted
        img_url = urljoin(addresses, img_url)
        # remove URLs like '/hsts-pixel.gif?c=3.2.5'
        try:
            pos = img_url.index("?")
            img_url = img_url[:pos]
        except ValueError:
            pass
        # finally, if the url is valid
        if is_valid(img_url):
            img_url = img_url.split('!', 1)[0]
            urls.append(img_url)
    return urls

# %%
def download(url, pathname):
    """
    Downloads a file given an URL and puts it in the folder `pathname`
    """
    # if path doesn't exist, make that path dir
    if not os.path.isdir(pathname):
        os.makedirs(pathname)
    # download the body of response by chunk, not immediately
    response = requests.get(url, stream=True)

    # get the total file size
    file_size = int(response.headers.get("Content-Length", 0))

    # get the file name
    prefix = url.split('/', 5)[4]
    prefix = prefix.split('.', 1)[0]
    filename = os.path.join(pathname, prefix + "_" + url.split("/")[-1])

    # progress bar, changing the unit to bytes instead of iteration (default by tqdm)
    progress = tqdm(response.iter_content(1024), "Downloading " + filename, total=file_size, unit="B", unit_scale=True, unit_divisor=1024)
    with open(filename, "wb") as f:
        for data in progress:
            # write data read to the file
            f.write(data)
            # update the progress bar manually
            progress.update(len(data))

# %%
def main(url, path):
    # get all images
    imgs = get_all_addresses(url)
    for img in imgs:
        # for each img, download it
        download(img, path)

# %% [markdown]
# ### Download the files

# %%
artists_list = open("wikiart_artists.txt", "r")
lines = artists_list.readlines()

for url_addr in range(len(lines)):
    print(lines[url_addr].rstrip("\n")  + "/all-works/text-list")
    main(lines[url_addr].rstrip("\n")  + "/all-works/text-list", "wikiart_dataset")
    
#main("https://www.wikiart.org/en/tsuruko-yamazaki/", "wikiart_dataset")
# Out:
# https://www.wikiart.org/en/jackson-pollock/all-works/text-list
# Extracting images: 100%|████████████████████| 86/86 [00:00<00:00, 10741.50it/s]
# Downloading wikiart_dataset\jackson-pollock_going-west-1935-1.jpg:   0%| | 2.00
# Downloading wikiart_dataset\jackson-pollock_figures-in-a-landscape.jpg:   0%| |
# Downloading wikiart_dataset\jackson-pollock_landscape-with-steer-1937.jpg:   0%
# Downloading wikiart_dataset\jackson-pollock_landscape-with-steer-1937-1.jpg:
# Downloading wikiart_dataset\jackson-pollock_the-flame-1938.jpg:   0%| | 2.00/1.
# Downloading wikiart_dataset\jackson-pollock_man-with-knife-1940.jpg:   0%| | 2.
# Downloading wikiart_dataset\jackson-pollock_circle-1941.jpg:   0%| | 2.00/1.22k
# Downloading wikiart_dataset\jackson-pollock_untitled-1941.jpg:   0%| | 2.00/1.2
# Downloading wikiart_dataset\jackson-pollock_untitled-1941-1.jpg:   0%| | 2.00/1
# Downloading wikiart_dataset\jackson-pollock_bird-1941.jpg:   0%| | 2.00/1.22k [
# Downloading wikiart_dataset\jackson-pollock_mask.jpg:   0%| | 2.00/1.22k [00:00
# Downloading wikiart_dataset\jackson-pollock_sheet-of-studies-1941.jpg:   0%| |
# Downloading wikiart_dataset\jackson-pollock_birth.jpg:   0%| | 2.00/1.22k [00:0
# Downloading wikiart_dataset\jackson-pollock_moon-woman-1942.jpg:   0%| | 2.00/1
# Downloading wikiart_dataset\jackson-pollock_animals-and-figures-1942-1.jpg:   0
# Downloading wikiart_dataset\jackson-pollock_male-and-female.jpg:   0%| | 2.00/1
# Downloading wikiart_dataset\jackson-pollock_stenographic-figure.jpg:   0%| | 2.
# Downloading wikiart_dataset\jackson-pollock_untitled-3.jpg:   0%| | 2.00/1.22k
# Downloading wikiart_dataset\jackson-pollock_the-she-wolf.jpg:   0%| | 2.00/1.22
# Downloading wikiart_dataset\jackson-pollock_blue-moby-dick.jpg:   0%| | 2.00/1.
# Downloading wikiart_dataset\jackson-pollock_composition-with-pouring-ii.jpg:
# Downloading wikiart_dataset\jackson-pollock_untitled-4.jpg:   0%| | 2.00/1.22k
# Downloading wikiart_dataset\jackson-pollock_mural-1943-1.jpg:   0%| | 2.00/1.22
# Downloading wikiart_dataset\jackson-pollock_the-moon-woman-cuts-the-circle-1943
# Downloading wikiart_dataset\jackson-pollock_untitled-1944.jpg:   0%| | 2.00/1.2
# Downloading wikiart_dataset\jackson-pollock_totem-lesson-2-1945.jpg:   0%| | 2.
# Downloading wikiart_dataset\jackson-pollock_pattern.jpg:   0%| | 2.00/1.22k [00
# Downloading wikiart_dataset\jackson-pollock_untitled.jpg:   0%| | 2.00/1.22k [0
# Downloading wikiart_dataset\jackson-pollock_eyes-in-the-heat-1946.jpg:   0%| |
# Downloading wikiart_dataset\jackson-pollock_shimmering-substance-1946-1.jpg:
# Downloading wikiart_dataset\jackson-pollock_the-tea-cup.jpg:   0%| | 2.00/1.22k
# Downloading wikiart_dataset\jackson-pollock_circumcision-january-1946-1.jpg:
# Downloading wikiart_dataset\jackson-pollock_the-key.jpg:   0%| | 2.00/1.22k [00
# Downloading wikiart_dataset\jackson-pollock_number-32-1947.jpg:   0%| | 2.00/1.
# Downloading wikiart_dataset\jackson-pollock_alchemy-1947.jpg:   0%| | 2.00/1.22
# Downloading wikiart_dataset\jackson-pollock_full-fathom-five.jpg:   0%| | 2.00/
# Downloading wikiart_dataset\jackson-pollock_galaxy-1947.jpg:   0%| | 1.27k/1.27
# Downloading wikiart_dataset\jackson-pollock_enchanted-forest-1947.jpg:   0%| |
# Downloading wikiart_dataset\jackson-pollock_lucifer-1947.jpg:   0%| | 557/557k
# Downloading wikiart_dataset\jackson-pollock_cathedral-1947.jpg:   0%| | 143/143
# Downloading wikiart_dataset\jackson-pollock_reflections-of-the-big-dipper-1947.
# Downloading wikiart_dataset\jackson-pollock_untitled-o-connor-thaw-770.jpg:   0
# Downloading wikiart_dataset\jackson-pollock_untitled-o-connor-thaw-771.jpg:   0
# Downloading wikiart_dataset\jackson-pollock_no-1-1948.jpg:   0%| | 2.00/1.22k [
# Downloading wikiart_dataset\jackson-pollock_number-23.jpg:   0%| | 2.00/1.22k [
# Downloading wikiart_dataset\jackson-pollock_number-3-1948.jpg:   0%| | 2.00/1.2
# Downloading wikiart_dataset\jackson-pollock_number-5-1948-1.jpg:   0%| | 2.00/1
# Downloading wikiart_dataset\jackson-pollock_number-4-gray-and-red-1948.jpg:   0
# Downloading wikiart_dataset\jackson-pollock_number-13a-arabesque-1948.jpg:   0%
# Downloading wikiart_dataset\jackson-pollock_summertime-number-9a-1948.jpg:   0%
# Downloading wikiart_dataset\jackson-pollock_composition-white-black-blue-and-re
# Downloading wikiart_dataset\jackson-pollock_number-6-1949.jpg:   0%| | 2.00/1.2
# Downloading wikiart_dataset\jackson-pollock_number-1.jpg:   0%| | 2.00/1.22k [0
# Downloading wikiart_dataset\jackson-pollock_number-8-detail.jpg:   0%| | 2.00/1
# Downloading wikiart_dataset\jackson-pollock_number-3-1.jpg:   0%| | 2.00/1.22k
# Downloading wikiart_dataset\jackson-pollock_number-7-out-of-the-web-1949.jpg:
# Downloading wikiart_dataset\jackson-pollock_number-10-1949.jpg:   0%| | 78.0/77
# Downloading wikiart_dataset\jackson-pollock_number-17-1949.jpg:   0%| | 370/370
# Downloading wikiart_dataset\jackson-pollock_number-12-1949.jpg:   0%| | 324/324
# Downloading wikiart_dataset\jackson-pollock_number-26-1949.jpg:   0%| | 100/99.
# Downloading wikiart_dataset\jackson-pollock_number-48-1949.jpg:   0%| | 257/256
# Downloading wikiart_dataset\jackson-pollock_number-8-1949.jpg:   0%| | 223/222k
# Downloading wikiart_dataset\jackson-pollock_untitled-green-silver-1949.jpg:   0
# Downloading wikiart_dataset\jackson-pollock_not_detected_185248.jpg:   0%| | 2.
# Downloading wikiart_dataset\jackson-pollock_number-1-lavender-mist-1950-1.jpg:
# Downloading wikiart_dataset\jackson-pollock_not_detected_185311.jpg:   0%| | 65
# Downloading wikiart_dataset\jackson-pollock_number-25.jpg:   0%| | 2.00/1.22k [
# Downloading wikiart_dataset\jackson-pollock_autumn-rhythm-number-30-1950.jpg:
# Downloading wikiart_dataset\jackson-pollock_mural-on-indian-red-ground-1950.jpg
# Downloading wikiart_dataset\jackson-pollock_one-number-31-1950.jpg:   0%| | 127
# Downloading wikiart_dataset\jackson-pollock_number-29-1950.jpg:   0%| | 169/169
# Downloading wikiart_dataset\jackson-pollock_number-32-1950.jpg:   0%| | 286/285
# Downloading wikiart_dataset\jackson-pollock_echo-1951.jpg:   0%| | 2.00/1.22k [
# Downloading wikiart_dataset\jackson-pollock_untitled-1951.jpg:   0%| | 2.00/1.2
# Downloading wikiart_dataset\jackson-pollock_number-14.jpg:   0%| | 2.00/1.22k [
# Downloading wikiart_dataset\jackson-pollock_number-2.jpg:   0%| | 2.00/1.22k [0
# Downloading wikiart_dataset\jackson-pollock_untitled-1951-1.jpg:   0%| | 311/31
# Downloading wikiart_dataset\jackson-pollock_black-white-number-20-1951.jpg:   0
# Downloading wikiart_dataset\jackson-pollock_number-4-1951.jpg:   0%| | 396/395k
# Downloading wikiart_dataset\jackson-pollock_blue-poles-number-11-1952-1.jpg:
# Downloading wikiart_dataset\jackson-pollock_convergence-1952.jpg:   0%| | 585/5
# Downloading wikiart_dataset\jackson-pollock_yellow-islands.jpg:   0%| | 2.00/1.
# Downloading wikiart_dataset\jackson-pollock_easter-and-the-totem.jpg:   0%| | 2
# Downloading wikiart_dataset\jackson-pollock_the-deep-1953.jpg:   0%| | 88.0/87.
# Downloading wikiart_dataset\jackson-pollock_ocean-greyness-1953.jpg:   0%| | 12
# Downloading wikiart_dataset\jackson-pollock_portrait-and-a-dream-1953.jpg:   0%
# https://www.wikiart.org/en/jean-helion/all-works/text-list
# Extracting images: 100%|█████████████████████| 40/40 [00:00<00:00, 9994.77it/s]
# Downloading wikiart_dataset\jean-helion_untitled-h-lion-29-1929.jpg:   0%| | 44
# Downloading wikiart_dataset\jean-helion_composition-orthogonale-1930.jpg:   0%|
# Downloading wikiart_dataset\jean-helion_untitled-h-lion-33-5f-1933.jpg:   0%| |
# Downloading wikiart_dataset\jean-helion_untitled-h-lion-h-33-1933.jpg:   0%| |
# Downloading wikiart_dataset\jean-helion_abstract-copmosition-1934.jpg:   0%| |
# Downloading wikiart_dataset\jean-helion_equilibrium-1934.jpg:   0%| | 46.0/45.2
# Downloading wikiart_dataset\jean-helion_abstraction-1934.jpg:   0%| | 52.0/51.9
# Downloading wikiart_dataset\jean-helion_composition-1934.jpg:   0%| | 93.0/92.7
# Downloading wikiart_dataset\jean-helion_untitled-h-lion-34-1934.jpg:   0%| | 39
# Downloading wikiart_dataset\jean-helion_ile-de-france-1935.jpg:   0%| | 89.0/88
# Downloading wikiart_dataset\jean-helion_equilibre-1936.jpg:   0%| | 27.0/26.1k
# Downloading wikiart_dataset\jean-helion_figure-rose-1937.jpg:   0%| | 81.0/80.8
# Downloading wikiart_dataset\jean-helion_au-cycliste-1939.jpg:   0%| | 42.0/41.7
# Downloading wikiart_dataset\jean-helion_etude-e-195-1939.jpg:   0%| | 49.0/48.6
# Downloading wikiart_dataset\jean-helion_etude-1939.jpg:   0%| | 49.0/48.6k [00:
# Downloading wikiart_dataset\jean-helion_fallen-figure-1939.jpg:   0%| | 64.0/63
# Downloading wikiart_dataset\jean-helion_untitled-1943.jpg:   0%| | 32.0/31.7k [
# Downloading wikiart_dataset\jean-helion_man-with-a-shoe-1944.jpg:   0%| | 42.0/
# Downloading wikiart_dataset\jean-helion_pegeen-1944.jpg:   0%| | 57.0/56.5k [00
# Downloading wikiart_dataset\jean-helion_a-rebours-1947.jpg:   0%| | 63.0/63.0k
# Downloading wikiart_dataset\jean-helion_big-pumpkin-event-1948.jpg:   0%| | 62.
# Downloading wikiart_dataset\jean-helion_nu-accoud-1949.jpg:   0%| | 106/105k [0
# Downloading wikiart_dataset\jean-helion_nu-accoud-1949-1.jpg:   0%| | 46.0/45.7
# Downloading wikiart_dataset\jean-helion_the-big-daily-read-grande-journalerie-1
# Downloading wikiart_dataset\jean-helion_leland-bell-reading-i-1951.jpg:   0%| |
# Downloading wikiart_dataset\jean-helion_nude-with-loaves-1952.jpg:   0%| | 92.0
# Downloading wikiart_dataset\jean-helion_untitled-1952.jpg:   0%| | 88.0/87.7k [
# Downloading wikiart_dataset\jean-helion_untitled-sketchbook-page-1955.jpg:   0%
# Downloading wikiart_dataset\jean-helion_untitled-sketchbook-page-1955-1.jpg:
# Downloading wikiart_dataset\jean-helion_untitled-skull-series-1957.jpg:   0%| |
# Downloading wikiart_dataset\jean-helion_untitled-1957.jpg:   0%| | 59.0/59.0k [
# Downloading wikiart_dataset\jean-helion_la-citrouille-et-son-reflet-1958.jpg:
# Downloading wikiart_dataset\jean-helion_page-de-musique-1962.jpg:   0%| | 47.0/
# Downloading wikiart_dataset\jean-helion_triptyque-du-dragon-1967.jpg:   0%| | 4
# Downloading wikiart_dataset\jean-helion_mannequinerie-en-solde-1978.jpg:   0%|
# Downloading wikiart_dataset\jean-helion_suite-puciere-1978.jpg:   0%| | 33.0/32
# Downloading wikiart_dataset\jean-helion_accident-1979.jpg:   0%| | 54.0/53.6k [
# Downloading wikiart_dataset\jean-helion_l-abstraction-le-peintre-et-le-modele-1
# Downloading wikiart_dataset\jean-helion_remake-1983.jpg:   0%| | 47.0/46.1k [00
# Downloading wikiart_dataset\jean-helion_unknown-title.jpg:   0%| | 75.0/74.5k [
# https://www.wikiart.org/en/joan-miro/all-works/text-list
# Extracting images: 100%|██████████████████| 200/200 [00:00<00:00, 12491.41it/s]
# Downloading wikiart_dataset\joan-miro_the-farmer.jpg:   0%| | 402/401k [00:00<0
# Downloading wikiart_dataset\joan-miro_portrait-of-a-young-girl.jpg:   0%| | 308
# Downloading wikiart_dataset\joan-miro_not_detected_227961.jpg:   0%| | 301/300k
# Downloading wikiart_dataset\joan-miro_still-life-with-rose.jpg:   0%| | 145/145
# Downloading wikiart_dataset\joan-miro_ciurana-the-path.jpg:   0%| | 48.0/47.5k
# Downloading wikiart_dataset\joan-miro_north-south.jpg:   0%| | 289/288k [00:00<
# Downloading wikiart_dataset\joan-miro_not_detected_227964.jpg:   0%| | 345/344k
# Downloading wikiart_dataset\joan-miro_portrait-of-e-c-ricart.jpg:   0%| | 154/1
# Downloading wikiart_dataset\joan-miro_portrait-of-v-nubiola.jpg:   0%| | 389/38
# Downloading wikiart_dataset\joan-miro_prades-the-village.jpg:   0%| | 144/143k
# Downloading wikiart_dataset\joan-miro_self-portrait.jpg:   0%| | 371/370k [00:0
# Downloading wikiart_dataset\joan-miro_house-with-palm-tree.jpg:   0%| | 204/203
# Downloading wikiart_dataset\joan-miro_not_detected_227963.jpg:   0%| | 282/282k
# Downloading wikiart_dataset\joan-miro_not_detected_227965.jpg:   0%| | 435/434k
# Downloading wikiart_dataset\joan-miro_portrait-of-hiberto-casany-the-chauffeur.
# Downloading wikiart_dataset\joan-miro_portrait-of-juanita-obrador.jpg:   0%| |
# Downloading wikiart_dataset\joan-miro_standing-nude.jpg:   0%| | 155/155k [00:0
# Downloading wikiart_dataset\joan-miro_still-life-with-coffee-mill.jpg:   0%| |
# Downloading wikiart_dataset\joan-miro_the-vegetable-garden-with-donkey.jpg:   0
# Downloading wikiart_dataset\joan-miro_the-waggon-tracks.jpg:   0%| | 224/223k [
# Downloading wikiart_dataset\joan-miro_mont-roig-vineyards-and-olive-tree.jpg:
# Downloading wikiart_dataset\joan-miro_not_detected_227962.jpg:   0%| | 287/286k
# Downloading wikiart_dataset\joan-miro_nude-with-mirror.jpg:   0%| | 625/625k [0
# Downloading wikiart_dataset\joan-miro_portrait-of-a-spanish-dancer.jpg:   0%| |
# Downloading wikiart_dataset\joan-miro_self-portrait-1.jpg:   0%| | 373/373k [00
# Downloading wikiart_dataset\joan-miro_horse-pipe-and-red-flower.jpg:   0%| | 58
# Downloading wikiart_dataset\joan-miro_the-table-still-life-with-rabbit.jpg:   0
# Downloading wikiart_dataset\joan-miro_standing-nude-1.jpg:   0%| | 97.0/96.6k [
# Downloading wikiart_dataset\joan-miro_the-farm-1922.jpg:   0%| | 484/484k [00:0
# Downloading wikiart_dataset\joan-miro_flowers-and-butterfly.jpg:   0%| | 289/28
# Downloading wikiart_dataset\joan-miro_the-carbide-lamp-1923.jpg:   0%| | 132/13
# Downloading wikiart_dataset\joan-miro_the-ear-of-corn-1923.jpg:   0%| | 183/182
# Downloading wikiart_dataset\joan-miro_the-farmer-s-wife-1923.jpg:   0%| | 258/2
# Downloading wikiart_dataset\joan-miro_the-tilled-field-1924.jpg:   0%| | 193/19
# Downloading wikiart_dataset\joan-miro_bottle-of-vine.jpg:   0%| | 272/271k [00:
# Downloading wikiart_dataset\joan-miro_bouquet-of-flowers-smile-of-my-blond.jpg:
# Downloading wikiart_dataset\joan-miro_catalan-landscape-the-hunter-1924.jpg:
# Downloading wikiart_dataset\joan-miro_catalan-peasant-with-a-guitar.jpg:   0%|
# Downloading wikiart_dataset\joan-miro_hermitage.jpg:   0%| | 27.0/26.8k [00:00<
# Downloading wikiart_dataset\joan-miro_maternity.jpg:   0%| | 170/170k [00:00<03
# Downloading wikiart_dataset\joan-miro_not_detected_227966.jpg:   0%| | 442/442k
# Downloading wikiart_dataset\joan-miro_the-hunter-1924.jpg:   0%| | 96.0/95.1k [
# Downloading wikiart_dataset\joan-miro_bathing-woman.jpg:   0%| | 46.0/45.2k [00
# Downloading wikiart_dataset\joan-miro_dancer.jpg:   0%| | 27.0/26.2k [00:00<00:
# Downloading wikiart_dataset\joan-miro_harlequin-s-carnival-1925.jpg:   0%| | 33
# Downloading wikiart_dataset\joan-miro_head-of-a-catalan-peasant-2.jpg:   0%| |
# Downloading wikiart_dataset\joan-miro_landscape-1925.jpg:   0%| | 20.0/19.7k [0
# Downloading wikiart_dataset\joan-miro_not_detected_227927.jpg:   0%| | 27.0/27.
# Downloading wikiart_dataset\joan-miro_not_detected_227967.jpg:   0%| | 354/353k
# Downloading wikiart_dataset\joan-miro_not_detected_227968.jpg:   0%| | 425/424k
# Downloading wikiart_dataset\joan-miro_not_detected_227969.jpg:   0%| | 632/631k
# Downloading wikiart_dataset\joan-miro_not_detected_227970.jpg:   0%| | 292/292k
# Downloading wikiart_dataset\joan-miro_not_detected_227983.jpg:   0%| | 142/142k
# Downloading wikiart_dataset\joan-miro_photo-this-is-the-color-of-my-dreams.jpg:
# Downloading wikiart_dataset\joan-miro_siesta.jpg:   0%| | 688/688k [00:00<03:39
# Downloading wikiart_dataset\joan-miro_stars-in-snails-sexes.jpg:   0%| | 33.0/3
# Downloading wikiart_dataset\joan-miro_the-birth-of-the-world.jpg:   0%| | 38.0/
# Downloading wikiart_dataset\joan-miro_dog-barking-at-the-moon.jpg:   0%| | 356/
# Downloading wikiart_dataset\joan-miro_nude.jpg:   0%| | 63.0/62.7k [00:00<00:47
# Downloading wikiart_dataset\joan-miro_person-throwing-a-stone-at-a-bird.jpg:
# Downloading wikiart_dataset\joan-miro_landscape-the-hare.jpg:   0%| | 26.0/25.8
# Downloading wikiart_dataset\joan-miro_landscape-with-snake.jpg:   0%| | 63.0/62
# Downloading wikiart_dataset\joan-miro_not_detected_227971.jpg:   0%| | 281/280k
# Downloading wikiart_dataset\joan-miro_painting.jpg:   0%| | 18.0/17.0k [00:00<0
# Downloading wikiart_dataset\joan-miro_the-circus-house.jpg:   0%| | 21.0/20.5k
# Downloading wikiart_dataset\joan-miro_tirador-in-the-arc.jpg:   0%| | 311/311k
# Downloading wikiart_dataset\joan-miro_painting-head-1927.jpg:   0%| | 132/131k
# Downloading wikiart_dataset\joan-miro_painting-1927.jpg:   0%| | 59.0/58.8k [00
# Downloading wikiart_dataset\joan-miro_dutch-interior.jpg:   0%| | 40.0/39.6k [0
# Downloading wikiart_dataset\joan-miro_dutch-interior-i.jpg:   0%| | 274/273k [0
# Downloading wikiart_dataset\joan-miro_dutch-interior-ii.jpg:   0%| | 2.00/1.22k
# Downloading wikiart_dataset\joan-miro_still-life-with-lamp-1928.jpg:   0%| | 40
# Downloading wikiart_dataset\joan-miro_portrait-of-mrs-mills-in-1750-after-const
# Downloading wikiart_dataset\joan-miro_cap-d-home.jpg:   0%| | 215/215k [00:00<0
# Downloading wikiart_dataset\joan-miro_composition.jpg:   0%| | 21.0/20.2k [00:0
# Downloading wikiart_dataset\joan-miro_drawing-collage-with-a-hat.jpg:   0%| | 3
# Downloading wikiart_dataset\joan-miro_painting-1.jpg:   0%| | 325/324k [00:00<0
# Downloading wikiart_dataset\joan-miro_painting-2.jpg:   0%| | 22.0/21.6k [00:00
# Downloading wikiart_dataset\joan-miro_character.jpg:   0%| | 23.0/22.0k [00:00<
# Downloading wikiart_dataset\joan-miro_fleur-femme-etoile-escargot.jpg:   0%| |
# Downloading wikiart_dataset\joan-miro_not_detected_227978.jpg:   0%| | 471/471k
# Downloading wikiart_dataset\joan-miro_not_detected_227987.jpg:   0%| | 83.0/82.
# Downloading wikiart_dataset\joan-miro_swallow-love.jpg:   0%| | 37.0/37.0k [00:
# Downloading wikiart_dataset\joan-miro_head-of-a-man.jpg:   0%| | 19.0/18.1k [00
# Downloading wikiart_dataset\joan-miro_not_detected_227972.jpg:   0%| | 259/259k
# Downloading wikiart_dataset\joan-miro_rope-and-people-i.jpg:   0%| | 49.0/49.0k
# Downloading wikiart_dataset\joan-miro_three-gifts.jpg:   0%| | 111/111k [00:00<
# Downloading wikiart_dataset\joan-miro_figures-in-front-of-a-metamorphosis.jpg:
# Downloading wikiart_dataset\joan-miro_man-and-woman-in-front-of-a-pile-of-excre
# Downloading wikiart_dataset\joan-miro_metamorphose.jpg:   0%| | 20.0/19.3k [00:
# Downloading wikiart_dataset\joan-miro_painting-1936.jpg:   0%| | 2.00/1.22k [00
# Downloading wikiart_dataset\joan-miro_naked-woman-climbing-a-staircase-1937.jpg
# Downloading wikiart_dataset\joan-miro_aidez-l-espagne-help-spain.jpg:   0%| | 9
# Downloading wikiart_dataset\joan-miro_not_detected_227982.jpg:   0%| | 143/143k
# Downloading wikiart_dataset\joan-miro_still-life-with-old-shoe.jpg:   0%| | 189
# Downloading wikiart_dataset\joan-miro_the-air-1937.jpg:   0%| | 584/583k [00:00
# Downloading wikiart_dataset\joan-miro_self-portrait-i.jpg:   0%| | 319/318k [00
# Downloading wikiart_dataset\joan-miro_a-star-caresses-the-breasts-of-a-negro-wo
# Downloading wikiart_dataset\joan-miro_portrait-ii.jpg:   0%| | 246/245k [00:00<
# Downloading wikiart_dataset\joan-miro_seated-woman-ii.jpg:   0%| | 213/213k [00
# Downloading wikiart_dataset\joan-miro_portrait-iv-1938.jpg:   0%| | 39.0/38.6k
# Downloading wikiart_dataset\joan-miro_a-dew-drop-falling-from-a-bird-s-wing-wak
# Downloading wikiart_dataset\joan-miro_the-escape-ladder.jpg:   0%| | 65.0/64.0k
# Downloading wikiart_dataset\joan-miro_the-escape-ladder-1940.jpg:   0%| | 2.00/
# Downloading wikiart_dataset\joan-miro_constellation-the-morning-star.jpg:   0%|
# Downloading wikiart_dataset\joan-miro_figure-at-night-guided-by-the-phosphoresc
# Downloading wikiart_dataset\joan-miro_not_detected_227931.jpg:   0%| | 219/218k
# Downloading wikiart_dataset\joan-miro_the-nightingale-s-song-at-midnight-and-th
# Downloading wikiart_dataset\joan-miro_the-poetess.jpg:   0%| | 153/153k [00:00<
# Downloading wikiart_dataset\joan-miro_ciphers-and-constellations-in-love-with-a
# Downloading wikiart_dataset\joan-miro_constellation-awakening-at-dawn.jpg:   0%
# Downloading wikiart_dataset\joan-miro_not_detected_227932.jpg:   0%| | 269/269k
# Downloading wikiart_dataset\joan-miro_not_detected_227933.jpg:   0%| | 479/479k
# Downloading wikiart_dataset\joan-miro_woman-encircled-by-the-flight-of-a-bird.j
# Downloading wikiart_dataset\joan-miro_painting-3.jpg:   0%| | 370/370k [00:00<0
# Downloading wikiart_dataset\joan-miro_painting-4.jpg:   0%| | 44.0/43.9k [00:00
# Downloading wikiart_dataset\joan-miro_not_detected_227934.jpg:   0%| | 243/242k
# Downloading wikiart_dataset\joan-miro_not_detected_227985.jpg:   0%| | 140/140k
# Downloading wikiart_dataset\joan-miro_the-bull-fight.jpg:   0%| | 27.0/26.9k [0
# Downloading wikiart_dataset\joan-miro_women-sonando-evasion.jpg:   0%| | 11.0/1
# Downloading wikiart_dataset\joan-miro_women-and-birds-at-sunrise.jpg:   0%| | 1
# Downloading wikiart_dataset\joan-miro_not_detected_227935.jpg:   0%| | 169/168k
# Downloading wikiart_dataset\joan-miro_not_detected_227936.jpg:   0%| | 141/140k
# Downloading wikiart_dataset\joan-miro_the-red-sun-1948.jpg:   0%| | 91.0/90.7k
# Downloading wikiart_dataset\joan-miro_figures-and-dog-in-front-of-the-sun.jpg:
# Downloading wikiart_dataset\joan-miro_woman-and-bird-in-the-moonlight.jpg:   0%
# Downloading wikiart_dataset\joan-miro_not_detected_227937.jpg:   0%| | 193/193k
# Downloading wikiart_dataset\joan-miro_painting-5.jpg:   0%| | 62.0/61.7k [00:00
# Downloading wikiart_dataset\joan-miro_woman-in-front-of-the-sun.jpg:   0%| | 36
# Downloading wikiart_dataset\joan-miro_dragonfly-with-red-tipped-wing-in-pursuit
# Downloading wikiart_dataset\joan-miro_the-sun-embracing-the-lover-1952.jpg:   0
# Downloading wikiart_dataset\joan-miro_ladders-cross-the-blue-sky-in-a-wheel-of-
# Downloading wikiart_dataset\joan-miro_series-i-1953.jpg:   0%| | 275/274k [00:0
# Downloading wikiart_dataset\joan-miro_the-smile-of-the-flamboyant-wings.jpg:
# Downloading wikiart_dataset\joan-miro_not_detected_227938.jpg:   0%| | 247/246k
# Downloading wikiart_dataset\joan-miro_not_detected_227980.jpg:   0%| | 463/462k
# Downloading wikiart_dataset\joan-miro_the-red-disk.jpg:   0%| | 236/235k [00:00
# Downloading wikiart_dataset\joan-miro_not_detected_227975.jpg:   0%| | 309/309k
# Downloading wikiart_dataset\joan-miro_blue-ii.jpg:   0%| | 170/170k [00:00<01:5
# Downloading wikiart_dataset\joan-miro_blue-iii.jpg:   0%| | 390/389k [00:00<02:
# Downloading wikiart_dataset\joan-miro_blue-i-1961.jpg:   0%| | 18.0/17.2k [00:0
# Downloading wikiart_dataset\joan-miro_not_detected_227939.jpg:   0%| | 165/164k
# Downloading wikiart_dataset\joan-miro_not_detected_227940.jpg:   0%| | 148/148k
# Downloading wikiart_dataset\joan-miro_not_detected_227941.jpg:   0%| | 67.0/66.
# Downloading wikiart_dataset\joan-miro_not_detected_227942.jpg:   0%| | 80.0/79.
# Downloading wikiart_dataset\joan-miro_not_detected_227974.jpg:   0%| | 173/172k
# Downloading wikiart_dataset\joan-miro_untitled-1964.jpg:   0%| | 107/106k [00:0
# Downloading wikiart_dataset\joan-miro_femme-iii.jpg:   0%| | 285/285k [00:00<02
# Downloading wikiart_dataset\joan-miro_painting-i.jpg:   0%| | 192/192k [00:00<0
# Downloading wikiart_dataset\joan-miro_not_detected_227943.jpg:   0%| | 162/161k
# Downloading wikiart_dataset\joan-miro_bird-s-flight-in-moonlight.jpg:   0%| | 1
# Downloading wikiart_dataset\joan-miro_not_detected_227944.jpg:   0%| | 936/936k
# Downloading wikiart_dataset\joan-miro_not_detected_227945.jpg:   0%| | 182/181k
# Downloading wikiart_dataset\joan-miro_not_detected_227946.jpg:   0%| | 135/134k
# Downloading wikiart_dataset\joan-miro_not_detected_227947.jpg:   0%| | 210/210k
# Downloading wikiart_dataset\joan-miro_not_detected_227958.jpg:   0%| | 441/441k
# Downloading wikiart_dataset\joan-miro_the-gold-of-the-azure.jpg:   0%| | 188/18
# Downloading wikiart_dataset\joan-miro_the-lark-s-wing-encircled-with-golden-blu
# Downloading wikiart_dataset\joan-miro_the-song-of-the-vowels.jpg:   0%| | 250/2
# Downloading wikiart_dataset\joan-miro_batement-ii.jpg:   0%| | 420/420k [00:00<
# Downloading wikiart_dataset\joan-miro_catalan-peasant-in-the-moonlight.jpg:   0
# Downloading wikiart_dataset\joan-miro_fascinating-personage.jpg:   0%| | 182/18
# Downloading wikiart_dataset\joan-miro_hair-pursued-by-2-planets.jpg:   0%| | 31
# Downloading wikiart_dataset\joan-miro_not_detected_227948.jpg:   0%| | 286/286k
# Downloading wikiart_dataset\joan-miro_not_detected_227949.jpg:   0%| | 152/152k
# Downloading wikiart_dataset\joan-miro_not_detected_227950.jpg:   0%| | 173/173k
# Downloading wikiart_dataset\joan-miro_not_detected_227951.jpg:   0%| | 182/182k
# Downloading wikiart_dataset\joan-miro_not_detected_227952.jpg:   0%| | 143/143k
# Downloading wikiart_dataset\joan-miro_not_detected_227960.jpg:   0%| | 277/277k
# Downloading wikiart_dataset\joan-miro_poema-i.jpg:   0%| | 268/268k [00:00<02:2
# Downloading wikiart_dataset\joan-miro_the-birth-of-day.jpg:   0%| | 256/256k [0
# Downloading wikiart_dataset\joan-miro_the-flight-of-the-dragonfly-in-front-of-t
# Downloading wikiart_dataset\joan-miro_not_detected_227976.jpg:   0%| | 178/177k
# Downloading wikiart_dataset\joan-miro_the-great-carnivore-1969.jpg:   0%| | 41.
# Downloading wikiart_dataset\joan-miro_the-matador-1969.jpg:   0%| | 92.0/91.9k
# Downloading wikiart_dataset\joan-miro_la-luna-verde-1972.jpg:   0%| | 2.00/1.22
# Downloading wikiart_dataset\joan-miro_not_detected_227954.jpg:   0%| | 328/328k
# Downloading wikiart_dataset\joan-miro_may-1968-1973.jpg:   0%| | 2.00/1.22k [00
# Downloading wikiart_dataset\joan-miro_not_detected_227955.jpg:   0%| | 156/156k
# Downloading wikiart_dataset\joan-miro_big-carpet.jpg:   0%| | 209/208k [00:00<0
# Downloading wikiart_dataset\joan-miro_not_detected_227953-1974.jpg:   0%| | 215
# Downloading wikiart_dataset\joan-miro_not_detected_227956.jpg:   0%| | 129/128k
# Downloading wikiart_dataset\joan-miro_not_detected_227957.jpg:   0%| | 244/244k
# Downloading wikiart_dataset\joan-miro_woman-before-the-luna.jpg:   0%| | 191/19
# Downloading wikiart_dataset\joan-miro_woman-in-front-of-the-sun-i.jpg:   0%| |
# Downloading wikiart_dataset\joan-miro_fireworks-i-1974.jpg:   0%| | 137/137k [0
# Downloading wikiart_dataset\joan-miro_hope-of-a-condemned-man-ii-1974.jpg:   0%
# Downloading wikiart_dataset\joan-miro_hope-of-a-condemned-man-iii-1974.jpg:   0
# Downloading wikiart_dataset\joan-miro_hope-of-a-condemned-man-i-1974.jpg:   0%|
# Downloading wikiart_dataset\joan-miro_not_detected_227979.jpg:   0%| | 272/271k
# Downloading wikiart_dataset\joan-miro_donna-wall.jpg:   0%| | 434/434k [00:00<0
# Downloading wikiart_dataset\joan-miro_carota.jpg:   0%| | 337/336k [00:00<02:35
# Downloading wikiart_dataset\joan-miro_not_detected_227986.jpg:   0%| | 78.0/77.
# Downloading wikiart_dataset\joan-miro_woman-and-bird-1983.jpg:   0%| | 2.00/1.2
# Downloading wikiart_dataset\joan-miro_flame-in-space-and-nude-woman.jpg:   0%|
# Downloading wikiart_dataset\joan-miro_a-courtyard-scene.jpg:   0%| | 192/191k [
# Downloading wikiart_dataset\joan-miro_not_detected_227959.jpg:   0%| | 281/280k
# Downloading wikiart_dataset\joan-miro_not_detected_227977.jpg:   0%| | 261/261k
# Downloading wikiart_dataset\joan-miro_not_detected_227981.jpg:   0%| | 362/361k
# Downloading wikiart_dataset\joan-miro_not_detected_227984.jpg:   0%| | 68.0/67.
# https://www.wikiart.org/en/jock-macdonald/all-works/text-list
# Extracting images: 100%|█████████████████████| 16/16 [00:00<00:00, 7996.77it/s]
# Downloading wikiart_dataset\jock-macdonald_day-break-modality-series-1936.jpg:
# Downloading wikiart_dataset\jock-macdonald_modality-series-spring-awakening-854
# Downloading wikiart_dataset\jock-macdonald_lake-o-hara-1941.jpg:   0%| | 95.0/9
# Downloading wikiart_dataset\jock-macdonald_bird-romance-1946.jpg:   0%| | 725/7
# Downloading wikiart_dataset\jock-macdonald_birds-1946.jpg:   0%| | 138/138k [00
# Downloading wikiart_dataset\jock-macdonald_untitled-1946.jpg:   0%| | 74.0/73.9
# Downloading wikiart_dataset\jock-macdonald_untitled-1946-1.jpg:   0%| | 522/521
# Downloading wikiart_dataset\jock-macdonald_fantasy-in-equilibrium-1948.jpg:   0
# Downloading wikiart_dataset\jock-macdonald_indian-myth-1948.jpg:   0%| | 440/44
# Downloading wikiart_dataset\jock-macdonald_fluctuating-planes-1952.jpg:   0%| |
# Downloading wikiart_dataset\jock-macdonald_from-a-riviera-window-1955.jpg:   0%
# Downloading wikiart_dataset\jock-macdonald_riviera-winter-colour-symphony-1955.
# Downloading wikiart_dataset\jock-macdonald_flood-tide-1957.jpg:   0%| | 345/344
# Downloading wikiart_dataset\jock-macdonald_primordial-fire-1957.jpg:   0%| | 47
# Downloading wikiart_dataset\jock-macdonald_legend-of-the-orient-1958.jpg:   0%|
# Downloading wikiart_dataset\jock-macdonald_untitled-bird.jpg:   0%| | 521/521k
# https://www.wikiart.org/en/john-ferren/all-works/text-list
# Extracting images: 100%|█████████████████████| 48/48 [00:00<00:00, 7993.59it/s]
# Downloading wikiart_dataset\john-ferren_st-tropez-abstract-1929.jpg:   0%| | 15
# Downloading wikiart_dataset\john-ferren_composition-la-carte-de-france-1931.jpg
# Downloading wikiart_dataset\john-ferren_untitled-no-8-1932.jpg:   0%| | 133/132
# Downloading wikiart_dataset\john-ferren_untitled-1932.jpg:   0%| | 69.0/68.1k [
# Downloading wikiart_dataset\john-ferren_untitled-1932-1.jpg:   0%| | 163/162k [
# Downloading wikiart_dataset\john-ferren_composition-1933.jpg:   0%| | 312/312k
# Downloading wikiart_dataset\john-ferren_composition-brun-1933.jpg:   0%| | 136/
# Downloading wikiart_dataset\john-ferren_composition-aux-plais-jaunes-1933.jpg:
# Downloading wikiart_dataset\john-ferren_grazioso-1933.jpg:   0%| | 175/174k [00
# Downloading wikiart_dataset\john-ferren_untitled-1933.jpg:   0%| | 59.0/58.1k [
# Downloading wikiart_dataset\john-ferren_mallorca-1934.jpg:   0%| | 16.0/15.5k [
# Downloading wikiart_dataset\john-ferren_composition-1937.jpg:   0%| | 288/287k
# Downloading wikiart_dataset\john-ferren_lutte-as-ciel-1937.jpg:   0%| | 430/429
# Downloading wikiart_dataset\john-ferren_sea-forms-1937.jpg:   0%| | 121/120k [0
# Downloading wikiart_dataset\john-ferren_the-desert-1938.jpg:   0%| | 173/173k [
# Downloading wikiart_dataset\john-ferren_rock-totems-1948.jpg:   0%| | 190/190k
# Downloading wikiart_dataset\john-ferren_three-rocks-1949.jpg:   0%| | 49.0/48.1
# Downloading wikiart_dataset\john-ferren_desert-landscape-1951.jpg:   0%| | 72.0
# Downloading wikiart_dataset\john-ferren_contemplations-on-geraniums-1952.jpg:
# Downloading wikiart_dataset\john-ferren_outdoors-1952.jpg:   0%| | 164/164k [00
# Downloading wikiart_dataset\john-ferren_ski-1952.jpg:   0%| | 47.0/46.1k [00:00
# Downloading wikiart_dataset\john-ferren_untitled-1952.jpg:   0%| | 150/149k [00
# Downloading wikiart_dataset\john-ferren_untitled-1952-1.jpg:   0%| | 27.0/26.1k
# Downloading wikiart_dataset\john-ferren_new-york-summer-landscape-1953.jpg:   0
# Downloading wikiart_dataset\john-ferren_red-spot-1954.jpg:   0%| | 45.0/44.5k [
# Downloading wikiart_dataset\john-ferren_branches-1955.jpg:   0%| | 80.0/79.5k [
# Downloading wikiart_dataset\john-ferren_the-bush-1955.jpg:   0%| | 120/120k [00
# Downloading wikiart_dataset\john-ferren_medeanus.jpg:   0%| | 100/99.4k [00:00<
# Downloading wikiart_dataset\john-ferren_untitled-1956.jpg:   0%| | 196/195k [00
# Downloading wikiart_dataset\john-ferren_untitled-i-1957.jpg:   0%| | 240/239k [
# Downloading wikiart_dataset\john-ferren_broken-blue-1958.jpg:   0%| | 150/150k
# Downloading wikiart_dataset\john-ferren_greenock-1958.jpg:   0%| | 78.0/77.6k [
# Downloading wikiart_dataset\john-ferren_navaho-1958.jpg:   0%| | 165/164k [00:0
# Downloading wikiart_dataset\john-ferren_untitled-1959.jpg:   0%| | 108/107k [00
# Downloading wikiart_dataset\john-ferren_yellow-field-1960.jpg:   0%| | 77.0/76.
# Downloading wikiart_dataset\john-ferren_blue-green-ground-1961.jpg:   0%| | 108
# Downloading wikiart_dataset\john-ferren_one-world-1961.jpg:   0%| | 222/221k [0
# Downloading wikiart_dataset\john-ferren_untitled-1961.jpg:   0%| | 94.0/93.6k [
# Downloading wikiart_dataset\john-ferren_the-witch-doctor-1963.jpg:   0%| | 196/
# Downloading wikiart_dataset\john-ferren_untitled-1963.jpg:   0%| | 132/132k [00
# Downloading wikiart_dataset\john-ferren_the-changeling-1964.jpg:   0%| | 157/15
# Downloading wikiart_dataset\john-ferren_quiet-1965.jpg:   0%| | 18.0/17.9k [00:
# Downloading wikiart_dataset\john-ferren_sidon-no-3-1965.jpg:   0%| | 119/119k [
# Downloading wikiart_dataset\john-ferren_red-rose-1966.jpg:   0%| | 77.0/76.1k [
# Downloading wikiart_dataset\john-ferren_rvg-1966.jpg:   0%| | 522/522k [00:00<0
# Downloading wikiart_dataset\john-ferren_abstract-composition-1968.jpg:   0%| |
# Downloading wikiart_dataset\john-ferren_composition.jpg:   0%| | 70.0/69.4k [00
# Downloading wikiart_dataset\john-ferren_paris-abstract.jpg:   0%| | 58.0/57.1k
# https://www.wikiart.org/en/leon-polk-smith/all-works/text-list
# Extracting images: 100%|█████████████████████| 17/17 [00:00<00:00, 4250.81it/s]
# Downloading wikiart_dataset\leon-polk-smith_homage-to-victory-boogie-woogie-1-1
# Downloading wikiart_dataset\leon-polk-smith_inch-squares-no-3-1949.jpg:   0%| |
# Downloading wikiart_dataset\leon-polk-smith_black-and-white-repeat-1953.jpg:
# Downloading wikiart_dataset\leon-polk-smith_kanawa-1956.jpg:   0%| | 56.0/55.5k
# Downloading wikiart_dataset\leon-polk-smith_untitled-1959.jpg:   0%| | 78.0/77.
# Downloading wikiart_dataset\leon-polk-smith_yellow-white-sun-1959.jpg:   0%| |
# Downloading wikiart_dataset\leon-polk-smith_correspondence-red-black-1962.jpg:
# Downloading wikiart_dataset\leon-polk-smith_correspondence-red-white-side-b-196
# Downloading wikiart_dataset\leon-polk-smith_untitled-1968.jpg:   0%| | 21.0/20.
# Downloading wikiart_dataset\leon-polk-smith_untitled-1968-1.jpg:   0%| | 44.0/4
# Downloading wikiart_dataset\leon-polk-smith_constellation-twelve-circles-1969.j
# Downloading wikiart_dataset\leon-polk-smith_end-gable-1972.jpg:   0%| | 18.0/17
# Downloading wikiart_dataset\leon-polk-smith_crossroads-grey-1978.jpg:   0%| | 1
# Downloading wikiart_dataset\leon-polk-smith_big-space-black-line-1990.jpg:   0%
# Downloading wikiart_dataset\leon-polk-smith_event-in-blue-1994.jpg:   0%| | 10.
# Downloading wikiart_dataset\leon-polk-smith_big-t.jpg:   0%| | 104/104k [00:00<
# Downloading wikiart_dataset\leon-polk-smith_oh-happy-day-constellation-series.j
# https://www.wikiart.org/en/lorser-feitelson/all-works/text-list
# Extracting images: 100%|████████████████████| 24/24 [00:00<00:00, 11983.73it/s]
# Downloading wikiart_dataset\lorser-feitelson_the-fountain-1923.jpg:   0%| | 70.
# Downloading wikiart_dataset\lorser-feitelson_genesis-2-1934.jpg:   0%| | 532/53
# Downloading wikiart_dataset\lorser-feitelson_flight-over-new-york-at-twilight-1
# Downloading wikiart_dataset\lorser-feitelson_post-surreal-configuration-eternal
# Downloading wikiart_dataset\lorser-feitelson_magical-forms-1945.jpg:   0%| | 11
# Downloading wikiart_dataset\lorser-feitelson_magical-space-forms-1948.jpg:   0%
# Downloading wikiart_dataset\lorser-feitelson_magical-space-forms-black-fuchsia-
# Downloading wikiart_dataset\lorser-feitelson_magical-space-forms-1951.jpg:   0%
# Downloading wikiart_dataset\lorser-feitelson_dichotomic-organization-stripes-19
# Downloading wikiart_dataset\lorser-feitelson_dichotomic-organization-1959.jpg:
# Downloading wikiart_dataset\lorser-feitelson_magical-space-forms-1962.jpg:   0%
# Downloading wikiart_dataset\lorser-feitelson_untitled-boulder-series-1962.jpg:
# Downloading wikiart_dataset\lorser-feitelson_untitled-1962.jpg:   0%| | 8.00/7.
# Downloading wikiart_dataset\lorser-feitelson_untitled-september-22-1964.jpg:
# Downloading wikiart_dataset\lorser-feitelson_untitled-1964.jpg:   0%| | 45.0/44
# Downloading wikiart_dataset\lorser-feitelson_untitled-black-and-white-lines-on-
# Downloading wikiart_dataset\lorser-feitelson_untitled-1966.jpg:   0%| | 43.0/43
# Downloading wikiart_dataset\lorser-feitelson_untitled-february-4-1967.jpg:   0%
# Downloading wikiart_dataset\lorser-feitelson_untitled-february-1970.jpg:   0%|
# Downloading wikiart_dataset\lorser-feitelson_untitled-january-30-1971.jpg:   0%
# Downloading wikiart_dataset\lorser-feitelson_archimage-2-1976.jpg:   0%| | 17.0
# Downloading wikiart_dataset\lorser-feitelson_untitled-april-30-1977.jpg:   0%|
# Downloading wikiart_dataset\lorser-feitelson_unknown-title.jpg:   0%| | 205/204
# Downloading wikiart_dataset\lorser-feitelson_untitled.jpg:   0%| | 67.0/66.7k [
# https://www.wikiart.org/en/louis-schanker/all-works/text-list
# Extracting images: 100%|████████████████████| 24/24 [00:00<00:00, 11986.58it/s]
# Downloading wikiart_dataset\louis-schanker_abstract-with-instruments-1932.jpg:
# Downloading wikiart_dataset\louis-schanker_beggars-1933.jpg:   0%| | 183/183k [
# Downloading wikiart_dataset\louis-schanker_polo-1937.jpg:   0%| | 151/151k [00:
# Downloading wikiart_dataset\louis-schanker_abstract-composition-1938.jpg:   0%|
# Downloading wikiart_dataset\louis-schanker_caf-1-1938.jpg:   0%| | 119/118k [00
# Downloading wikiart_dataset\louis-schanker_study-in-green-and-black-1939.jpg:
# Downloading wikiart_dataset\louis-schanker_untitled-1939.jpg:   0%| | 107/106k
# Downloading wikiart_dataset\louis-schanker_aerial-act-1940.jpg:   0%| | 101/101
# Downloading wikiart_dataset\louis-schanker_football-1941.jpg:   0%| | 154/154k
# Downloading wikiart_dataset\louis-schanker_forms-in-action-1941.jpg:   0%| | 84
# Downloading wikiart_dataset\louis-schanker_wall-handball-study-1942.jpg:   0%|
# Downloading wikiart_dataset\louis-schanker_abstract-composition-1944.jpg:   0%|
# Downloading wikiart_dataset\louis-schanker_three-figures.jpg:   0%| | 210/209k
# Downloading wikiart_dataset\louis-schanker_carnival-1948.jpg:   0%| | 71.0/70.0
# Downloading wikiart_dataset\louis-schanker_untitled-1949.jpg:   0%| | 188/187k
# Downloading wikiart_dataset\louis-schanker_football-3-1950.jpg:   0%| | 83.0/82
# Downloading wikiart_dataset\louis-schanker_circle-image-no-25-1954.jpg:   0%| |
# Downloading wikiart_dataset\louis-schanker_circle-image.jpg:   0%| | 229/228k [
# Downloading wikiart_dataset\louis-schanker_green-forms-1957.jpg:   0%| | 257/25
# Downloading wikiart_dataset\louis-schanker_untitled-abstract-composition-1968.j
# Downloading wikiart_dataset\louis-schanker_abstract-carved-wood-sculpture.jpg:
# Downloading wikiart_dataset\louis-schanker_abstraction.jpg:   0%| | 144/143k [0
# Downloading wikiart_dataset\louis-schanker_football.jpg:   0%| | 328/328k [00:0
# Downloading wikiart_dataset\louis-schanker_untitled.jpg:   0%| | 306/305k [00:0
# https://www.wikiart.org/en/louise-nevelson/all-works/text-list
# Extracting images: 100%|█████████████████████| 15/15 [00:00<00:00, 7496.97it/s]
# Downloading wikiart_dataset\louise-nevelson_clown-tight-rope-walker-1942.jpg:
# Downloading wikiart_dataset\louise-nevelson_atmosphere-and-environment-x-1969.j
# Downloading wikiart_dataset\louise-nevelson_atmoshere-and-environment-xii-1970.
# Downloading wikiart_dataset\louise-nevelson_seventh-decade-garden-ix-x-1970.jpg
# Downloading wikiart_dataset\louise-nevelson_night-tree-1971.jpg:   0%| | 335/33
# Downloading wikiart_dataset\louise-nevelson_sky-covenant-1973.jpg:   0%| | 42.0
# Downloading wikiart_dataset\louise-nevelson_sky-jag-iv-1974.jpg:   0%| | 99.0/9
# Downloading wikiart_dataset\louise-nevelson_transparent-horizon-1975.jpg:   0%|
# Downloading wikiart_dataset\louise-nevelson_night-presence-ii-1976.jpg:   0%| |
# Downloading wikiart_dataset\louise-nevelson_sky-hook-maquette-1977.jpg:   0%| |
# Downloading wikiart_dataset\louise-nevelson_sky-tree-1977.jpg:   0%| | 32.0/31.
# Downloading wikiart_dataset\louise-nevelson_full-moon-1980.jpg:   0%| | 93.0/92
# Downloading wikiart_dataset\louise-nevelson_night-sail-1983.jpg:   0%| | 147/14
# Downloading wikiart_dataset\louise-nevelson_sky-landscape-1988.jpg:   0%| | 38.
# Downloading wikiart_dataset\louise-nevelson_voyage-no-ii.jpg:   0%| | 89.0/88.6
# https://www.wikiart.org/en/mark-rothko/all-works/text-list
# Extracting images: 100%|███████████████████| 163/163 [00:00<00:00, 8144.47it/s]
# Downloading wikiart_dataset\mark-rothko_interior.jpg:   0%| | 162/162k [00:00<0
# Downloading wikiart_dataset\mark-rothko_rural-scene.jpg:   0%| | 126/126k [00:0
# Downloading wikiart_dataset\mark-rothko_self-portrait.jpg:   0%| | 127/126k [00
# Downloading wikiart_dataset\mark-rothko_street-scene.jpg:   0%| | 122/121k [00:
# Downloading wikiart_dataset\mark-rothko_untitled-14.jpg:   0%| | 133/132k [00:0
# Downloading wikiart_dataset\mark-rothko_entance-to-subway.jpg:   0%| | 123/122k
# Downloading wikiart_dataset\mark-rothko_untitled-standing-man-and-woman-1938.jp
# Downloading wikiart_dataset\mark-rothko_untitled-15.jpg:   0%| | 107/106k [00:0
# Downloading wikiart_dataset\mark-rothko_not_detected_242139.jpg:   0%| | 113/11
# Downloading wikiart_dataset\mark-rothko_untitled-19.jpg:   0%| | 49.0/48.6k [00
# Downloading wikiart_dataset\mark-rothko_underground-fantasy.jpg:   0%| | 119/11
# Downloading wikiart_dataset\mark-rothko_sacrifice-of-iphigenia.jpg:   0%| | 123
# Downloading wikiart_dataset\mark-rothko_untitled-13.jpg:   0%| | 130/130k [00:0
# Downloading wikiart_dataset\mark-rothko_untitled-16.jpg:   0%| | 154/154k [00:0
# Downloading wikiart_dataset\mark-rothko_untitled-17.jpg:   0%| | 136/135k [00:0
# Downloading wikiart_dataset\mark-rothko_untitled-18.jpg:   0%| | 168/168k [00:0
# Downloading wikiart_dataset\mark-rothko_aubade.jpg:   0%| | 48.0/47.4k [00:00<0
# Downloading wikiart_dataset\mark-rothko_not_detected_242118.jpg:   0%| | 115/11
# Downloading wikiart_dataset\mark-rothko_gethsemane-1944.jpg:   0%| | 2.00/1.22k
# Downloading wikiart_dataset\mark-rothko_slow-swirl-at-the-edge-of-the-sea.jpg:
# Downloading wikiart_dataset\mark-rothko_untitled-3.jpg:   0%| | 170/169k [00:00
# Downloading wikiart_dataset\mark-rothko_hierarchical-birds.jpg:   0%| | 180/180
# Downloading wikiart_dataset\mark-rothko_archaic-idol.jpg:   0%| | 134/134k [00:
# Downloading wikiart_dataset\mark-rothko_not_detected_242121.jpg:   0%| | 136/13
# Downloading wikiart_dataset\mark-rothko_not_detected_242126.jpg:   0%| | 138/13
# Downloading wikiart_dataset\mark-rothko_untitled-2.jpg:   0%| | 93.0/92.4k [00:
# Downloading wikiart_dataset\mark-rothko_not_detected_242119.jpg:   0%| | 150/14
# Downloading wikiart_dataset\mark-rothko_primeval-landscape.jpg:   0%| | 113/112
# Downloading wikiart_dataset\mark-rothko_rites-of-lilith.jpg:   0%| | 134/133k [
# Downloading wikiart_dataset\mark-rothko_not_detected_242122.jpg:   0%| | 110/11
# Downloading wikiart_dataset\mark-rothko_tentacles-of-memory.jpg:   0%| | 118/11
# Downloading wikiart_dataset\mark-rothko_untitled-1.jpg:   0%| | 66.0/65.0k [00:
# Downloading wikiart_dataset\mark-rothko_untitled-14b.jpg:   0%| | 105/105k [00:
# Downloading wikiart_dataset\mark-rothko_yellow-cherry-orange.jpg:   0%| | 44.0/
# Downloading wikiart_dataset\mark-rothko_no-9-1947.jpg:   0%| | 189/189k [00:00<
# Downloading wikiart_dataset\mark-rothko_multiform-1948.jpg:   0%| | 68.0/67.8k
# Downloading wikiart_dataset\mark-rothko_no-1-untitled.jpg:   0%| | 38.0/37.6k [
# Downloading wikiart_dataset\mark-rothko_no-5-no-24.jpg:   0%| | 25.0/24.7k [00:
# Downloading wikiart_dataset\mark-rothko_no-9.jpg:   0%| | 117/117k [00:00<01:10
# Downloading wikiart_dataset\mark-rothko_not_detected_242115.jpg:   0%| | 118/11
# Downloading wikiart_dataset\mark-rothko_not_detected_242116.jpg:   0%| | 130/12
# Downloading wikiart_dataset\mark-rothko_untitled-1948.jpg:   0%| | 61.0/60.5k [
# Downloading wikiart_dataset\mark-rothko_untitled-1948-1.jpg:   0%| | 48.0/47.6k
# Downloading wikiart_dataset\mark-rothko_untitled-1948-2.jpg:   0%| | 14.0/13.4k
# Downloading wikiart_dataset\mark-rothko_untitled.jpg:   0%| | 114/114k [00:00<0
# Downloading wikiart_dataset\mark-rothko_no-21-1949-0.jpg:   0%| | 2.00/1.22k [0
# Downloading wikiart_dataset\mark-rothko_no-19.jpg:   0%| | 77.0/76.4k [00:00<01
# Downloading wikiart_dataset\mark-rothko_no-21.jpg:   0%| | 144/143k [00:00<01:3
# Downloading wikiart_dataset\mark-rothko_no-24.jpg:   0%| | 79.0/78.3k [00:00<01
# Downloading wikiart_dataset\mark-rothko_no-3-no-13.jpg:   0%| | 45.0/44.2k [00:
# Downloading wikiart_dataset\mark-rothko_untitled-1949-2.jpg:   0%| | 2.00/1.22k
# Downloading wikiart_dataset\mark-rothko_violet-black-orange-yellow-on-white-and
# Downloading wikiart_dataset\mark-rothko_untitled-1949.jpg:   0%| | 35.0/34.8k [
# Downloading wikiart_dataset\mark-rothko_untitled-1949-1.jpg:   0%| | 11.0/10.9k
# Downloading wikiart_dataset\mark-rothko_no-1.jpg:   0%| | 104/104k [00:00<00:54
# Downloading wikiart_dataset\mark-rothko_no-10.jpg:   0%| | 328/327k [00:00<03:2
# Downloading wikiart_dataset\mark-rothko_no-5-no-22.jpg:   0%| | 380/380k [00:00
# Downloading wikiart_dataset\mark-rothko_white-center.jpg:   0%| | 222/222k [00:
# Downloading wikiart_dataset\mark-rothko_no-2.jpg:   0%| | 87.0/86.2k [00:00<00:
# Downloading wikiart_dataset\mark-rothko_no-18.jpg:   0%| | 118/118k [00:00<01:0
# Downloading wikiart_dataset\mark-rothko_no-2-no-7-and-no-2-1951.jpg:   0%| | 33
# Downloading wikiart_dataset\mark-rothko_number-24-untitled-1951.jpg:   0%| | 78
# Downloading wikiart_dataset\mark-rothko_no-8-1952.jpg:   0%| | 100/99.3k [00:00
# Downloading wikiart_dataset\mark-rothko_untitled-6.jpg:   0%| | 2.00/1.22k [00:
# Downloading wikiart_dataset\mark-rothko_untitled-10.jpg:   0%| | 90.0/89.2k [00
# Downloading wikiart_dataset\mark-rothko_untitled-blue-green-and-brown-1952.jpg:
# Downloading wikiart_dataset\mark-rothko_green-and-maroon.jpg:   0%| | 48.0/48.0
# Downloading wikiart_dataset\mark-rothko_no-61-rust-and-blue.jpg:   0%| | 53.0/5
# Downloading wikiart_dataset\mark-rothko_untitled-purple-white-and-red-1953.jpg:
# Downloading wikiart_dataset\mark-rothko_untitled-4.jpg:   0%| | 2.00/1.22k [00:
# Downloading wikiart_dataset\mark-rothko_untitled-yellow-red-and-blue-1953.jpg:
# Downloading wikiart_dataset\mark-rothko_blue-over-red-1953.jpg:   0%| | 75.0/74
# Downloading wikiart_dataset\mark-rothko_no-3-1953.jpg:   0%| | 54.0/53.4k [00:0
# Downloading wikiart_dataset\mark-rothko_cat-newyork.jpg:   0%| | 115/114k [00:0
# Downloading wikiart_dataset\mark-rothko_no-9-dark-over-light-earth.jpg:   0%| |
# Downloading wikiart_dataset\mark-rothko_not_detected_242128.jpg:   0%| | 164/16
# Downloading wikiart_dataset\mark-rothko_ochre-and-red-on-red.jpg:   0%| | 48.0/
# Downloading wikiart_dataset\mark-rothko_united-blue-yellow-green-on-red-1954.jp
# Downloading wikiart_dataset\mark-rothko_no-7-dark-over-light-1954.jpg:   0%| |
# Downloading wikiart_dataset\mark-rothko_no-6-yellow-white-blue-over-yellow-on-g
# Downloading wikiart_dataset\mark-rothko_no-1-royal-red-and-blue-1954.jpg:   0%|
# Downloading wikiart_dataset\mark-rothko_earth-green.jpg:   0%| | 529/528k [00:0
# Downloading wikiart_dataset\mark-rothko_red-and-orange.jpg:   0%| | 25.0/24.7k
# Downloading wikiart_dataset\mark-rothko_untitled-red-blue-orange-1955.jpg:   0%
# Downloading wikiart_dataset\mark-rothko_untitled-1955.jpg:   0%| | 30.0/29.0k [
# Downloading wikiart_dataset\mark-rothko_green-and-tangerine-on-red.jpg:   0%| |
# Downloading wikiart_dataset\mark-rothko_orange-and-yellow-1956.jpg:   0%| | 2.0
# Downloading wikiart_dataset\mark-rothko_orange-and-yellow.jpg:   0%| | 2.00/1.2
# Downloading wikiart_dataset\mark-rothko_untitled-red-1956.jpg:   0%| | 30.0/29.
# Downloading wikiart_dataset\mark-rothko_yellow-band.jpg:   0%| | 191/191k [00:0
# Downloading wikiart_dataset\mark-rothko_no-20-1957.jpg:   0%| | 55.0/54.5k [00:
# Downloading wikiart_dataset\mark-rothko_no-46.jpg:   0%| | 2.00/1.22k [00:00<00
# Downloading wikiart_dataset\mark-rothko_not_detected_242135.jpg:   0%| | 1.52k/
# Downloading wikiart_dataset\mark-rothko_ochre-and-red-on-red-1.jpg:   0%| | 50.
# Downloading wikiart_dataset\mark-rothko_purple-brown.jpg:   0%| | 37.0/36.1k [0
# Downloading wikiart_dataset\mark-rothko_red-and-brown.jpg:   0%| | 22.0/21.1k [
# Downloading wikiart_dataset\mark-rothko_red-white-and-brown.jpg:   0%| | 340/34
# Downloading wikiart_dataset\mark-rothko_white-on-red.jpg:   0%| | 2.00/1.22k [0
# Downloading wikiart_dataset\mark-rothko_black-in-deep-red-1957.jpg:   0%| | 32.
# Downloading wikiart_dataset\mark-rothko_no-16-1957.jpg:   0%| | 41.0/40.6k [00:
# Downloading wikiart_dataset\mark-rothko_untitled-no-11-1957.jpg:   0%| | 14.0/1
# Downloading wikiart_dataset\mark-rothko_no-13-white-and-red-on-yellow-1958.jpg:
# Downloading wikiart_dataset\mark-rothko_black-on-maroon.jpg:   0%| | 14.0/14.0k
# Downloading wikiart_dataset\mark-rothko_black-on-maroon-1.jpg:   0%| | 13.0/12.
# Downloading wikiart_dataset\mark-rothko_black-on-maroon-4.jpg:   0%| | 67.0/66.
# Downloading wikiart_dataset\mark-rothko_no-37-no-19-slate-blue-and-brown-on-plu
# Downloading wikiart_dataset\mark-rothko_four-darks-in-red-1958.jpg:   0%| | 18.
# Downloading wikiart_dataset\mark-rothko_composition-1958.jpg:   0%| | 113/112k
# Downloading wikiart_dataset\mark-rothko_black-on-maroon-2.jpg:   0%| | 9.00/8.2
# Downloading wikiart_dataset\mark-rothko_black-on-maroon-3.jpg:   0%| | 11.0/10.
# Downloading wikiart_dataset\mark-rothko_lavender-and-mulberry.jpg:   0%| | 103/
# Downloading wikiart_dataset\mark-rothko_no-301.jpg:   0%| | 11.0/10.3k [00:00<0
# ...
# Downloading wikiart_dataset\willem-de-kooning_abstraction-1950.jpg:   0%| | 0.9
# Downloading wikiart_dataset\willem-de-kooning_excavation.jpg:   0%| | 538/537k
# Downloading wikiart_dataset\willem-de-kooning_untitled-1950.jpg:   0%| | 225/22
# Downloading wikiart_dataset\willem-de-kooning_untitled-1950-1.jpg:   0%| | 224/
# Downloading wikiart_dataset\willem-de-kooning_woman-1950.jpg:   0%| | 162/161k
# Downloading wikiart_dataset\willem-de-kooning_two-woman-iv.jpg:   0%| | 127/127
# Downloading wikiart_dataset\willem-de-kooning_woman-and-bicycle.jpg:   0%| | 25
# Downloading wikiart_dataset\willem-de-kooning_woman-i.jpg:   0%| | 231/231k [00
# Downloading wikiart_dataset\willem-de-kooning_woman-v-1952-53-oil-charcoal-on-c
# Downloading wikiart_dataset\willem-de-kooning_marilyn-monroe-1954.jpg:   0%| |
# Downloading wikiart_dataset\willem-de-kooning_two-women-in-the-country.jpg:   0
# Downloading wikiart_dataset\willem-de-kooning_gotham-news.jpg:   0%| | 643/643k
# Downloading wikiart_dataset\willem-de-kooning_meg.jpg:   0%| | 52.0/52.0k [00:0
# Downloading wikiart_dataset\willem-de-kooning_composition.jpg:   0%| | 175/174k
# Downloading wikiart_dataset\willem-de-kooning_easter-monday.jpg:   0%| | 179/17
# Downloading wikiart_dataset\willem-de-kooning_saturday-night.jpg:   0%| | 73.0/
# Downloading wikiart_dataset\willem-de-kooning_park-rosenberg.jpg:   0%| | 130/1
# Downloading wikiart_dataset\willem-de-kooning_suburb-in-havana.jpg:   0%| | 99.
# Downloading wikiart_dataset\willem-de-kooning_untitled-8.jpg:   0%| | 98.0/97.4
# Downloading wikiart_dataset\willem-de-kooning_merritt-parkway-1959.jpg:   0%| |
# Downloading wikiart_dataset\willem-de-kooning_untitled-verso-untitled.jpg:   0%
# Downloading wikiart_dataset\willem-de-kooning_door-to-the-river.jpg:   0%| | 62
# Downloading wikiart_dataset\willem-de-kooning_clam-diggers.jpg:   0%| | 229/228
# Downloading wikiart_dataset\willem-de-kooning_reclining-man-john-f-kennedy.jpg:
# Downloading wikiart_dataset\willem-de-kooning_woman.jpg:   0%| | 108/108k [00:0
# Downloading wikiart_dataset\willem-de-kooning_mae-west.jpg:   0%| | 206/206k [0
# Downloading wikiart_dataset\willem-de-kooning_sphinx.jpg:   0%| | 248/248k [00:
# Downloading wikiart_dataset\willem-de-kooning_two-figures.jpg:   0%| | 227/226k
# Downloading wikiart_dataset\willem-de-kooning_untitled-2.jpg:   0%| | 135/134k
# Downloading wikiart_dataset\willem-de-kooning_untitled-3.jpg:   0%| | 217/216k
# Downloading wikiart_dataset\willem-de-kooning_woman-2.jpg:   0%| | 110/110k [00
# Downloading wikiart_dataset\willem-de-kooning_woman-3.jpg:   0%| | 247/247k [00
# Downloading wikiart_dataset\willem-de-kooning_woman-sag-harbour.jpg:   0%| | 23
# Downloading wikiart_dataset\willem-de-kooning_brooding-woman.jpg:   0%| | 54.0/
# Downloading wikiart_dataset\willem-de-kooning_pink-lady.jpg:   0%| | 264/263k [
# Downloading wikiart_dataset\willem-de-kooning_untitled-4.jpg:   0%| | 289/289k
# Downloading wikiart_dataset\willem-de-kooning_woman-4.jpg:   0%| | 112/111k [00
# Downloading wikiart_dataset\willem-de-kooning_woman-red-hair-large-mouth-large-
# Downloading wikiart_dataset\willem-de-kooning_women-singing-ii.jpg:   0%| | 31.
# Downloading wikiart_dataset\willem-de-kooning_two-figures-in-a-landscape.jpg:
# Downloading wikiart_dataset\willem-de-kooning_seated-woman-2.jpg:   0%| | 188/1
# Downloading wikiart_dataset\willem-de-kooning_untitled-1967.jpg:   0%| | 22.0/2
# Downloading wikiart_dataset\willem-de-kooning_untitled-1967-1.jpg:   0%| | 20.0
# Downloading wikiart_dataset\willem-de-kooning_untitled-5.jpg:   0%| | 205/204k
# Downloading wikiart_dataset\willem-de-kooning_white-nude.jpg:   0%| | 264/263k
# Downloading wikiart_dataset\willem-de-kooning_untitled-6.jpg:   0%| | 62.0/61.2
# Downloading wikiart_dataset\willem-de-kooning_figure-at-gerard-beach.jpg:   0%|
# Downloading wikiart_dataset\willem-de-kooning_landscape-at-stanton-street.jpg:
# Downloading wikiart_dataset\willem-de-kooning_untitled-woman.jpg:   0%| | 83.0/
# Downloading wikiart_dataset\willem-de-kooning_with-love.jpg:   0%| | 60.0/59.9k
# Downloading wikiart_dataset\willem-de-kooning_two-trees-on-mary-street-amen.jpg
# Downloading wikiart_dataset\willem-de-kooning_untitled-xi.jpg:   0%| | 145/144k
# Downloading wikiart_dataset\willem-de-kooning_whose-name-was-writ-in-water.jpg:
# Downloading wikiart_dataset\willem-de-kooning_devil-at-the-keyboard.jpg:   0%|
# Downloading wikiart_dataset\willem-de-kooning_untitled-i.jpg:   0%| | 784/784k
# Downloading wikiart_dataset\willem-de-kooning_untitled-iii.jpg:   0%| | 124/124
# Downloading wikiart_dataset\willem-de-kooning_untitled-xii.jpg:   0%| | 82.0/81
# Downloading wikiart_dataset\willem-de-kooning_untitled-v-1983.jpg:   0%| | 75.0
# Downloading wikiart_dataset\willem-de-kooning_untitled-2-from-quatre-lithograph
# Downloading wikiart_dataset\willem-de-kooning_untitled-1986.jpg:   0%| | 205/20
# Downloading wikiart_dataset\willem-de-kooning_landscape-of-a-woman.jpg:   0%| |
# Downloading wikiart_dataset\willem-de-kooning_untitled-7.jpg:   0%| | 288/287k
# Downloading wikiart_dataset\willem-de-kooning_woman-with-a-green-and-beige-back
# https://www.wikiart.org/en/wolfgang-paalen/all-works/text-list
# Extracting images: 100%|█████████████████████| 35/35 [00:00<00:00, 8746.98it/s]
# Downloading wikiart_dataset\wolfgang-paalen_les-tours-de-lumi-re-1936.jpg:   0%
# Downloading wikiart_dataset\wolfgang-paalen_l-heure-exacte-ii-1936.jpg:   0%| |
# Downloading wikiart_dataset\wolfgang-paalen_metamorphose-interrompue-1936.jpg:
# Downloading wikiart_dataset\wolfgang-paalen_fumage-1937.jpg:   0%| | 68.0/67.3k
# Downloading wikiart_dataset\wolfgang-paalen_study-for-totem-landscape-of-my-chi
# Downloading wikiart_dataset\wolfgang-paalen_fata-alaska-1937.jpg:   0%| | 170/1
# Downloading wikiart_dataset\wolfgang-paalen_les-etrangers-1937.jpg:   0%| | 37.
# Downloading wikiart_dataset\wolfgang-paalen_forbidden-land-1937.jpg:   0%| | 1.
# Downloading wikiart_dataset\wolfgang-paalen_genius-of-the-species-1938.jpg:   0
# Downloading wikiart_dataset\wolfgang-paalen_taches-solaires-1938.jpg:   0%| | 1
# Downloading wikiart_dataset\wolfgang-paalen_ciel-de-pieuvre-1938.jpg:   0%| | 8
# Downloading wikiart_dataset\wolfgang-paalen_untitled-fumage-encrage-1938.jpg:
# Downloading wikiart_dataset\wolfgang-paalen_combat-des-princes-saturniens-iii-1
# Downloading wikiart_dataset\wolfgang-paalen_space-unbound-1941.jpg:   0%| | 97.
# Downloading wikiart_dataset\wolfgang-paalen_eroun-1944.jpg:   0%| | 83.0/82.3k
# Downloading wikiart_dataset\wolfgang-paalen_messenger-from-the-three-poles-1949
# Downloading wikiart_dataset\wolfgang-paalen_untitled-automatic-drawing-1950.jpg
# Downloading wikiart_dataset\wolfgang-paalen_untitled-composition-1951.jpg:   0%
# Downloading wikiart_dataset\wolfgang-paalen_l-enclume-1952.jpg:   0%| | 139/138
# Downloading wikiart_dataset\wolfgang-paalen_beatrice-perdue-1953.jpg:   0%| | 1
# Downloading wikiart_dataset\wolfgang-paalen_untitled-automatic-drawing-1954.jpg
# Downloading wikiart_dataset\wolfgang-paalen_that-s-life-1958.jpg:   0%| | 105/1
# Downloading wikiart_dataset\wolfgang-paalen_combat-de-princes-saturniens-iii.jp
# Downloading wikiart_dataset\wolfgang-paalen_nuage-articul-ii.jpg:   0%| | 54.0/
# Downloading wikiart_dataset\wolfgang-paalen_s-urs-obsidiennes.jpg:   0%| | 815/
# Downloading wikiart_dataset\wolfgang-paalen_la-femme-blonde.jpg:   0%| | 44.0/4
# Downloading wikiart_dataset\wolfgang-paalen_la-roue-de-l-orage.jpg:   0%| | 44.
# Downloading wikiart_dataset\wolfgang-paalen_les-cosmogones-stage.jpg:   0%| | 1
# Downloading wikiart_dataset\wolfgang-paalen_paysage-boreal.jpg:   0%| | 54.0/53
# Downloading wikiart_dataset\wolfgang-paalen_personages.jpg:   0%| | 106/105k [0
# Downloading wikiart_dataset\wolfgang-paalen_rencontre-sur-une-plage.jpg:   0%|
# Downloading wikiart_dataset\wolfgang-paalen_selam-trilogy.jpg:   0%| | 107/106k
# Downloading wikiart_dataset\wolfgang-paalen_tete.jpg:   0%| | 33.0/32.0k [00:00
# Downloading wikiart_dataset\wolfgang-paalen_tripolar.jpg:   0%| | 95.0/95.0k [0
# Downloading wikiart_dataset\wolfgang-paalen_untitled-1.jpg:   0%| | 49.0/49.0k
# https://www.wikiart.org/en/yves-klein/all-works/text-list
# Extracting images: 100%|█████████████████████| 98/98 [00:00<00:00, 7532.93it/s]
# Downloading wikiart_dataset\yves-klein_untitled-drawing.jpg:   0%| | 307/307k [
# Downloading wikiart_dataset\yves-klein_horse.jpg:   0%| | 221/221k [00:00<01:54
# Downloading wikiart_dataset\yves-klein_untitled-drawing-1.jpg:   0%| | 231/231k
# Downloading wikiart_dataset\yves-klein_untitled-drawing-2.jpg:   0%| | 231/231k
# Downloading wikiart_dataset\yves-klein_christ-carrying-the-cross.jpg:   0%| | 2
# Downloading wikiart_dataset\yves-klein_landscape.jpg:   0%| | 220/219k [00:00<0
# Downloading wikiart_dataset\yves-klein_monochrome-red-theater.jpg:   0%| | 154/
# Downloading wikiart_dataset\yves-klein_monochrome-yellow-red-and-green-theater.
# Downloading wikiart_dataset\yves-klein_expression-of-the-universe-of-the-color-
# Downloading wikiart_dataset\yves-klein_untitled-blue-monochrome-1955.jpg:   0%|
# Downloading wikiart_dataset\yves-klein_untitled-yellow-pink-monochrome-1955.jpg
# Downloading wikiart_dataset\yves-klein_untitled-green-monochrome-1955.jpg:   0%
# Downloading wikiart_dataset\yves-klein_untitled-blue-monochrome-1955-1.jpg:   0
# Downloading wikiart_dataset\yves-klein_untitled-pink-monochrome-1955.jpg:   0%|
# Downloading wikiart_dataset\yves-klein_untitled-orange-monochrome-1956.jpg:   0
# Downloading wikiart_dataset\yves-klein_untitled-yellow-monochrome-1956.jpg:   0
# Downloading wikiart_dataset\yves-klein_untitled-blue-monochrome-1956.jpg:   0%|
# Downloading wikiart_dataset\yves-klein_untitled-green-monochrome-1956.jpg:   0%
# Downloading wikiart_dataset\yves-klein_untitled-red-monochrome-1956.jpg:   0%|
# Downloading wikiart_dataset\yves-klein_untitled-blue-monochrome-1956-1.jpg:   0
# Downloading wikiart_dataset\yves-klein_untitled-blue-monochrome-1956-2.jpg:   0
# Downloading wikiart_dataset\yves-klein_untitled-pink-monochrome-1956.jpg:   0%|
# Downloading wikiart_dataset\yves-klein_globe-blue.jpg:   0%| | 15.0/15.0k [00:0
# Downloading wikiart_dataset\yves-klein_monochrome-vert.jpg:   0%| | 188/187k [0
# Downloading wikiart_dataset\yves-klein_monochrome-red-untitled.jpg:   0%| | 67.
# Downloading wikiart_dataset\yves-klein_untitled-blue-monochrome.jpg:   0%| | 23
# Downloading wikiart_dataset\yves-klein_untitled-drawing-3.jpg:   0%| | 104/103k
# Downloading wikiart_dataset\yves-klein_untitled-white-monochrome-1957.jpg:   0%
# Downloading wikiart_dataset\yves-klein_a-minute-s-blue-fire-painting-1957.jpg:
# Downloading wikiart_dataset\yves-klein_black-monochrome-1957.jpg:   0%| | 149/1
# Downloading wikiart_dataset\yves-klein_untitled-white-monochrome-1957-1.jpg:
# Downloading wikiart_dataset\yves-klein_untitled-red-monochrome-1957.jpg:   0%|
# Downloading wikiart_dataset\yves-klein_untitled-blue-monochrome-1957.jpg:   0%|
# Downloading wikiart_dataset\yves-klein_untitled-blue-monochrome-1957-1.jpg:   0
# Downloading wikiart_dataset\yves-klein_untitled-blue-monochrome-1957-2.jpg:   0
# Downloading wikiart_dataset\yves-klein_untitled-blue-plate-1957.jpg:   0%| | 17
# Downloading wikiart_dataset\yves-klein_untitled-pink-monochrome-1957.jpg:   0%|
# Downloading wikiart_dataset\yves-klein_untitled-pink-monochrome-1957-1.jpg:   0
# Downloading wikiart_dataset\yves-klein_not_detected_216333.jpg:   0%| | 72.0/71
# Downloading wikiart_dataset\yves-klein_monochrome-pink-untitled.jpg:   0%| | 28
# Downloading wikiart_dataset\yves-klein_untitled-drawing-4.jpg:   0%| | 156/155k
# Downloading wikiart_dataset\yves-klein_untitled-blue-monochrome-1959.jpg:   0%|
# Downloading wikiart_dataset\yves-klein_untitled-blue-monochrome-1959-1.jpg:   0
# Downloading wikiart_dataset\yves-klein_untitled-blue-monochrome-1959-2.jpg:   0
# Downloading wikiart_dataset\yves-klein_blue-monochrome-pierced-by-fire-1959.jpg
# Downloading wikiart_dataset\yves-klein_untitled-monogold-1959.jpg:   0%| | 33.0
# Downloading wikiart_dataset\yves-klein_untitled-monogold-1959-1.jpg:   0%| | 54
# Downloading wikiart_dataset\yves-klein_anthropometry.jpg:   0%| | 19.0/18.4k [0
# Downloading wikiart_dataset\yves-klein_anthropometry-of-the-blue-period.jpg:
# Downloading wikiart_dataset\yves-klein_blue.jpg:   0%| | 170/169k [00:00<01:29,
# Downloading wikiart_dataset\yves-klein_monochrome-blue-gold-pink-silver-black.j
# Downloading wikiart_dataset\yves-klein_untitled-anthropometry-1960.jpg:   0%| |
# Downloading wikiart_dataset\yves-klein_untitled-blue-monochrome-1960.jpg:   0%|
# Downloading wikiart_dataset\yves-klein_untitled-blue-monochrome-1960-1.jpg:   0
# Downloading wikiart_dataset\yves-klein_untitled-pink-monochrome-1960.jpg:   0%|
# Downloading wikiart_dataset\yves-klein_silence-is-golden-1960.jpg:   0%| | 22.0
# Downloading wikiart_dataset\yves-klein_resonance-1960.jpg:   0%| | 16.0/15.7k [
# Downloading wikiart_dataset\yves-klein_untitled-monogold-1960.jpg:   0%| | 21.0
# Downloading wikiart_dataset\yves-klein_ho-ho-1960.jpg:   0%| | 51.0/50.6k [00:0
# Downloading wikiart_dataset\yves-klein_leap-into-the-void-1960.jpg:   0%| | 48.
# Downloading wikiart_dataset\yves-klein_untitled-color-fire-painting-1960.jpg:
# Downloading wikiart_dataset\yves-klein_untitled-cosmogony-1960.jpg:   0%| | 53.
# Downloading wikiart_dataset\yves-klein_le-rose-du-bleu-re-22-1960.jpg:   0%| |
# Downloading wikiart_dataset\yves-klein_ex-voto-dedicated-to-saint-rita-of-casci
# Downloading wikiart_dataset\yves-klein_fire-painting-1.jpg:   0%| | 95.0/94.3k
# Downloading wikiart_dataset\yves-klein_gold-leaf-on-panel.jpg:   0%| | 178/177k
# Downloading wikiart_dataset\yves-klein_people-begin-to-fly.jpg:   0%| | 698/697
# Downloading wikiart_dataset\yves-klein_untitled-anthropometry-ant-123-1961.jpg:
# Downloading wikiart_dataset\yves-klein_fire-painting-f6-1961.jpg:   0%| | 61.0/
# Downloading wikiart_dataset\yves-klein_fire-painting-f25-1961.jpg:   0%| | 56.0
# Downloading wikiart_dataset\yves-klein_fire-painting-f31-1961.jpg:   0%| | 66.0
# Downloading wikiart_dataset\yves-klein_fire-painting-f36-1961.jpg:   0%| | 79.0
# Downloading wikiart_dataset\yves-klein_california-1961.jpg:   0%| | 7.00/6.91k
# Downloading wikiart_dataset\yves-klein_golden-balls-1961.jpg:   0%| | 71.0/70.3
# Downloading wikiart_dataset\yves-klein_untitled-color-fire-painting-1961.jpg:
# Downloading wikiart_dataset\yves-klein_untitled-color-fire-painting-1961-1.jpg:
# Downloading wikiart_dataset\yves-klein_untitled-fire-painting-1961.jpg:   0%| |
# Downloading wikiart_dataset\yves-klein_a-rain-of-pleasure-1961.jpg:   0%| | 55.
# Downloading wikiart_dataset\yves-klein_wind-of-voyage-1961.jpg:   0%| | 48.0/47
# Downloading wikiart_dataset\yves-klein_anthropometries-of-the-blue-period.jpg:
# Downloading wikiart_dataset\yves-klein_assemblage-of-used-paint-rollers-1962.jp
# Downloading wikiart_dataset\yves-klein_portrait-relief-pr3-portrait-of-claude-p
# Downloading wikiart_dataset\yves-klein_the-beheaded-boy-and-the-priest.jpg:   0
# Downloading wikiart_dataset\yves-klein_the-venus-of-alexandria-venus-blue.jpg:
# Downloading wikiart_dataset\yves-klein_tree-large-blue-sponge.jpg:   0%| | 117/
# Downloading wikiart_dataset\yves-klein_untitled-fire-color-painting.jpg:   0%|
# Downloading wikiart_dataset\yves-klein_untitled-color-fire-painting-1962.jpg:
# Downloading wikiart_dataset\yves-klein_blue-agreement.jpg:   0%| | 576/576k [00
# Downloading wikiart_dataset\yves-klein_dying.jpg:   0%| | 162/162k [00:00<01:20
# Downloading wikiart_dataset\yves-klein_fire-painting.jpg:   0%| | 79.0/78.0k [0
# Downloading wikiart_dataset\yves-klein_great-blue-cannibalism-tribute-to-tennes
# Downloading wikiart_dataset\yves-klein_international-klein-blue.jpg:   0%| | 1.
# Downloading wikiart_dataset\yves-klein_moon-ii.jpg:   0%| | 202/201k [00:00<01:
# Downloading wikiart_dataset\yves-klein_nike-big.jpg:   0%| | 180/180k [00:00<01
# Downloading wikiart_dataset\yves-klein_re-11.jpg:   0%| | 666/665k [00:00<03:50
# Downloading wikiart_dataset\yves-klein_relief-sponge.jpg:   0%| | 54.0/53.1k [0
# Downloading wikiart_dataset\yves-klein_the-wave.jpg:   0%| | 133/132k [00:00<01
# Downloading wikiart_dataset\yves-klein_untitled-fire-painting.jpg:   0%| | 23.0

# %% [markdown]
# ### Sort the .txt file alphabetically

# %%
txt = "wikiart_artists.txt"

f = open(txt , "r")
lines = f.readlines()
f.close()
lines.sort()

f = open(txt , "w")
for line in lines:
    f.write(line)
    
f.flush()
f.close()
